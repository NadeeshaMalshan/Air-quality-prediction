# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)


#import libraries

# %%
# Mount Google Drive to access files
from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/Air quality prediction/air-quality-observations.csv'

df=pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
display(df.head())
# Out:
#   device_id                  date_time location_description   latitude  \
# 0  ems-b879  2023-01-17T00:26:09+00:00            Fairyland -37.546758
# 1  ems-b879  2023-01-17T02:41:07+00:00            Fairyland -37.546758
# 2  ems-b879  2023-01-17T03:26:07+00:00            Fairyland -37.546758
# 3  ems-b879  2023-01-15T05:11:27+00:00            Fairyland -37.546758
# 4  ems-b879  2022-12-23T19:45:10+00:00            Fairyland -37.546758
#
#     longitude  pm1  pm25  pm10  ozone  nitrogen_dioxide  carbon_monoxide  \
# 0  143.823172    3     3     4     70                97            -1006
# 1  143.823172    2     2     2     75               104              218
# 2  143.823172    2     2     2     61               104              743
# 3  143.823172    0     0     0     70               119            -2143
# 4  143.823172    3     4     4     65               119            -4766
#
#   air_quality_category                   point
# 0                 Fair  -37.546758, 143.823172
# 1                 Fair  -37.546758, 143.823172
# 2                 Fair  -37.546758, 143.823172
# 3                 Fair  -37.546758, 143.823172
# 4                 Fair  -37.546758, 143.823172

# %% [markdown]
# # Scalling

# %%
# Visualizations
# ii) Histograms
num_cols = ["PM1","PM25","PM10","O3","NO2","CO"]
df_cleaned[num_cols].hist(bins=30, figsize=(10,6))
plt.tight_layout(); plt.show()

# Save the plot
plt.savefig('/content/drive/MyDrive/Air quality prediction/eda_visualizations/wothoutScale.png')
plt.show()
# MinMax scaling
from sklearn.preprocessing import MinMaxScaler

df_scaled=df_cleaned.copy()
scaler= MinMaxScaler()
scale_cols=['PM1','PM25','PM10','O3','NO2','CO']
df_scaled[scale_cols]=scaler.fit_transform(df_cleaned[scale_cols])
df_scaled.head()
# Out:
#          ID                      Time   Location   Latitude   longitude  PM1  \
# 3  ems-b879 2023-01-15 05:11:27+00:00  Fairyland -37.546758  143.823172  0.0
# 4  ems-b879 2022-12-23 19:45:10+00:00  Fairyland -37.546758  143.823172  0.6
# 5  ems-b879 2022-12-23 20:30:10+00:00  Fairyland -37.546758  143.823172  0.6
# 6  ems-b879 2022-12-23 21:30:09+00:00  Fairyland -37.546758  143.823172  0.2
# 7  ems-b879 2022-12-23 22:00:10+00:00  Fairyland -37.546758  143.823172  0.4
#
#        PM25  PM10        O3       NO2        CO    AQ                   Point
# 3  0.000000   0.0  0.733333  0.736842  1.000000  Fair  -37.546758, 143.823172
# 4  0.571429   0.4  0.677778  0.736842  0.361800  Fair  -37.546758, 143.823172
# 5  0.714286   0.6  0.577778  0.608187  0.425547  Fair  -37.546758, 143.823172
# 6  0.142857   0.1  0.477778  0.473684  0.574453  Fair  -37.546758, 143.823172
# 7  0.285714   0.2  0.677778  0.695906  0.510706  Fair  -37.546758, 143.823172

# %%
#  Histograms(after scalling)
num_cols = ["PM1","PM25","PM10","O3","NO2","CO"]
df_scaled[num_cols].hist(bins=30, figsize=(10,6))
plt.tight_layout();
# Save the plot
plt.savefig('/content/drive/MyDrive/Air quality prediction/eda_visualizations/withScale.png')
plt.show()
